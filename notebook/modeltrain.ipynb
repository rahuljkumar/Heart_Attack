# %%
#Basic Import
import pandas as pd
import numpy as np

#Importing the Scaler for numerical features
from sklearn.preprocessing import RobustScaler


#Importing Train Test Split and GridSearchCV for hyperparamater tuning
from sklearn.model_selection import train_test_split, GridSearchCV

#Importing various models
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

#Importing model evaluation metrics
from sklearn.metrics import accuracy_score, classification_report

from sklearn.model_selection import GridSearchCV

# %%
#Reading the cleaned dataset
df=pd.read_csv('data/heart_without_duplicate.csv')

# %%
#Display first 5 rows of dataset
df.head()
# Out:
#    Unnamed: 0  age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  \
# 0           0   63    1   3     145   233    1        0       150     0
# 1           1   37    1   2     130   250    0        1       187     0
# 2           2   41    0   1     130   204    0        0       172     0
# 3           3   56    1   1     120   236    0        1       178     0
# 4           4   57    0   0     120   354    0        1       163     1
#
#    oldpeak  slp  caa  thall  output
# 0      2.3    0    0      1       1
# 1      3.5    0    0      2       1
# 2      1.4    2    0      2       1
# 3      0.8    2    0      2       1
# 4      0.6    2    0      2       1

# %%
#Removing the first column (unamed column)
df = df.iloc[: , 1:]
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
#Creating a copy of the dataframe
df1 = df

# %%
#Creating a list of categorical and numberical features
categorcial_features = ['sex','exng','caa','cp','fbs','restecg','slp','thall']
numerical_features = ["age","trtbps","chol","thalachh","oldpeak"]

# %%
#Creating a dataframe with the Independent variables
X = df1.drop(columns=['output'],axis=1)
X.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall
# 0    0      1
# 1    0      2
# 2    0      2
# 3    0      2
# 4    0      2

# %%
#Display the Independent variables
X.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall'],
#       dtype='object')

# %%
#Create a dataframe with the Dependent variable
Y = df1[['output']]
Y.head()
# Out:
#    output
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
#Checking the shape of Y
Y.shape
# Out:
# (302, 1)

# %% [markdown]
# The categorical variables are already label encoded in the dataset hence we will not require any further encoding

# %%
#Train test split
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 40)
print("The shape of X_train is      ", X_train.shape)
print("The shape of X_test is       ",X_test.shape)
print("The shape of y_train is      ",y_train.shape)
print("The shape of y_test is       ",y_test.shape)
# Out:
# The shape of X_train is       (241, 13)
# The shape of X_test is        (61, 13)
# The shape of y_train is       (241, 1)
# The shape of y_test is        (61, 1)

# %%
#Instantiating the scaler for numerical variable
scaler = RobustScaler()

# %%
#Scaling the numerical features
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#Define classifiers and their respective parameter grids for hyperparameter tuning
classifiers = {
    'Random Forest': (RandomForestClassifier(), {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10]
    }),
    'Gradient Boosting': (GradientBoostingClassifier(), {
        'n_estimators': [50, 100, 150],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 4, 5]
    }),
    'SVM': (SVC(), {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf'],
        'gamma': ['scale', 'auto']
    }),
    'KNN': (KNeighborsClassifier(), {
        'n_neighbors': [3, 5, 7],
        'weights': ['uniform', 'distance']
    }),
    'Logistic Regression': (LogisticRegression(), {
        'C': [0.1, 1, 10],
    }),
    'XGBoost': (XGBClassifier(), {
        'n_estimators': [100, 200, 300],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 4, 5]
    }),
    'CatBoost': (CatBoostClassifier(), {
        'iterations': [50, 100, 150],
        'learning_rate': [0.01, 0.1, 0.2],
        'depth': [3, 4, 5]
    }),
    'AdaBoost': (AdaBoostClassifier(), {
        'n_estimators': [50, 100, 150],
        'learning_rate': [0.01, 0.1, 0.2]
    }),
    'Decision Tree': (DecisionTreeClassifier(), {
        'max_depth': [None, 5, 10, 15],
        'min_samples_split': [2, 5, 10]
    })
}

#Hyperparameter tuning and evaluation for each classifier
for clf_name, (clf, param_grid) in classifiers.items():
    grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    
    # Print the best hyperparameters for the current classifier
    print(f'Best Hyperparameters for {clf_name}: {grid_search.best_params_}')

    # Make predictions on the test set
    y_pred = grid_search.predict(X_test)
    
    # Calculate accuracy score
    accuracy = accuracy_score(y_test, y_pred)
    print(f'Accuracy for {clf_name}: {accuracy:.2f}')

    # Generate and print the classification report
    report = classification_report(y_test, y_pred)
    print(f'Classification Report for {clf_name}:\n{report}\n')
# Out:
# c:\Users\jrahu\Music\Heart_Attack\henv\lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Best Hyperparameters for Random Forest: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 100}
# Accuracy for Random Forest: 0.89
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86        26
#            1       0.89      0.91      0.90        35
#
#     accuracy                           0.89        61
#    macro avg       0.88      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61
# c:\Users\jrahu\Music\Heart_Attack\henv\lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Hyperparameters for Gradient Boosting: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 100}
# Accuracy for Gradient Boosting: 0.84
# Classification Report for Gradient Boosting:
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80        26
#            1       0.84      0.89      0.86        35
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.83      0.83        61
# weighted avg       0.84      0.84      0.84        61
# c:\Users\jrahu\Music\Heart_Attack\henv\lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\jrahu\Music\Heart_Attack\henv\lib\site-packages\sklearn\neighbors\_classification.py:228: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Best Hyperparameters for SVM: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Accuracy for SVM: 0.89
# Classification Report for SVM:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86        26
#            1       0.89      0.91      0.90        35
#
#     accuracy                           0.89        61
#    macro avg       0.88      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61
#
#
# Best Hyperparameters for KNN: {'n_neighbors': 5, 'weights': 'uniform'}
# Accuracy for KNN: 0.92
# Classification Report for KNN:
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90        26
#            1       0.89      0.97      0.93        35
#
#     accuracy                           0.92        61
#    macro avg       0.93      0.91      0.91        61
# weighted avg       0.92      0.92      0.92        61
# c:\Users\jrahu\Music\Heart_Attack\henv\lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Hyperparameters for Logistic Regression: {'C': 1}
# Accuracy for Logistic Regression: 0.89
# Classification Report for Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86        26
#            1       0.89      0.91      0.90        35
#
#     accuracy                           0.89        61
#    macro avg       0.88      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61
#
#
# Best Hyperparameters for XGBoost: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100}
# Accuracy for XGBoost: 0.85
# Classification Report for XGBoost:
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82        26
#            1       0.86      0.89      0.87        35
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61
#
#
# 0:	learn: 0.6642611	total: 1.04ms	remaining: 51ms
# 1:	learn: 0.6404726	total: 3.43ms	remaining: 82.4ms
# 2:	learn: 0.6202594	total: 4.29ms	remaining: 67.3ms
# 3:	learn: 0.5975464	total: 5.02ms	remaining: 57.7ms
# 4:	learn: 0.5833869	total: 5.68ms	remaining: 51.2ms
# 5:	learn: 0.5649725	total: 6.38ms	remaining: 46.8ms
# 6:	learn: 0.5485475	total: 7.05ms	remaining: 43.3ms
# 7:	learn: 0.5305938	total: 7.72ms	remaining: 40.5ms
# 8:	learn: 0.5221157	total: 8.45ms	remaining: 38.5ms
# 9:	learn: 0.5091346	total: 9.18ms	remaining: 36.7ms
# 10:	learn: 0.4986058	total: 9.77ms	remaining: 34.6ms
# 11:	learn: 0.4894876	total: 10.4ms	remaining: 32.9ms
# 12:	learn: 0.4783490	total: 11.1ms	remaining: 31.6ms
# 13:	learn: 0.4684006	total: 11.8ms	remaining: 30.3ms
# 14:	learn: 0.4594807	total: 12.5ms	remaining: 29.1ms
# 15:	learn: 0.4532450	total: 13.1ms	remaining: 27.9ms
# 16:	learn: 0.4474357	total: 13.9ms	remaining: 26.9ms
# 17:	learn: 0.4409882	total: 14.8ms	remaining: 26.3ms
# 18:	learn: 0.4334187	total: 16.1ms	remaining: 26.3ms
# 19:	learn: 0.4262693	total: 17.1ms	remaining: 25.7ms
# 20:	learn: 0.4185802	total: 17.8ms	remaining: 24.6ms
# 21:	learn: 0.4153332	total: 18.4ms	remaining: 23.4ms
# 22:	learn: 0.4109870	total: 19.1ms	remaining: 22.5ms
# 23:	learn: 0.4074372	total: 19.8ms	remaining: 21.4ms
# 24:	learn: 0.4033074	total: 20.4ms	remaining: 20.4ms
# 25:	learn: 0.3984131	total: 21.2ms	remaining: 19.5ms
# 26:	learn: 0.3920754	total: 21.9ms	remaining: 18.6ms
# 27:	learn: 0.3887167	total: 22.6ms	remaining: 17.7ms
# 28:	learn: 0.3834437	total: 23.2ms	remaining: 16.8ms
# 29:	learn: 0.3788717	total: 23.9ms	remaining: 15.9ms
# 30:	learn: 0.3757069	total: 24.5ms	remaining: 15ms
# 31:	learn: 0.3714787	total: 25.2ms	remaining: 14.2ms
# 32:	learn: 0.3679677	total: 25.9ms	remaining: 13.4ms
# 33:	learn: 0.3639758	total: 26.6ms	remaining: 12.5ms
# 34:	learn: 0.3613435	total: 27.3ms	remaining: 11.7ms
# 35:	learn: 0.3584036	total: 28.3ms	remaining: 11ms
# 36:	learn: 0.3560527	total: 29.4ms	remaining: 10.3ms
# 37:	learn: 0.3535491	total: 30.1ms	remaining: 9.51ms
# 38:	learn: 0.3507655	total: 30.8ms	remaining: 8.69ms
# 39:	learn: 0.3483268	total: 31.5ms	remaining: 7.87ms
# 40:	learn: 0.3459555	total: 32.2ms	remaining: 7.07ms
# 41:	learn: 0.3417927	total: 32.9ms	remaining: 6.27ms
# 42:	learn: 0.3400839	total: 33.6ms	remaining: 5.46ms
# 43:	learn: 0.3376586	total: 34.2ms	remaining: 4.66ms
# 44:	learn: 0.3354756	total: 34.9ms	remaining: 3.88ms
# 45:	learn: 0.3336172	total: 35.6ms	remaining: 3.09ms
# 46:	learn: 0.3313017	total: 36.3ms	remaining: 2.32ms
# 47:	learn: 0.3287123	total: 37.1ms	remaining: 1.54ms
# 48:	learn: 0.3268553	total: 37.7ms	remaining: 770us
# 49:	learn: 0.3248230	total: 38.4ms	remaining: 0us
# Best Hyperparameters for CatBoost: {'depth': 4, 'iterations': 50, 'learning_rate': 0.1}
# Accuracy for CatBoost: 0.93
# Classification Report for CatBoost:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        26
#            1       0.94      0.94      0.94        35
#
#     accuracy                           0.93        61
#    macro avg       0.93      0.93      0.93        61
# weighted avg       0.93      0.93      0.93        61
# c:\Users\jrahu\Music\Heart_Attack\henv\lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Hyperparameters for AdaBoost: {'learning_rate': 0.1, 'n_estimators': 50}
# Accuracy for AdaBoost: 0.90
# Classification Report for AdaBoost:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        26
#            1       0.91      0.91      0.91        35
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61
#
#
# Best Hyperparameters for Decision Tree: {'max_depth': 5, 'min_samples_split': 2}
# Accuracy for Decision Tree: 0.80
# Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77        26
#            1       0.83      0.83      0.83        35
#
#     accuracy                           0.80        61
#    macro avg       0.80      0.80      0.80        61
# weighted avg       0.80      0.80      0.80        61

# %% [markdown]
# CatBoost has given the best accuracy (93%) out of all the models we have tried.
# Best Hyperparameters for CatBoost: {'depth': 4, 'iterations': 50, 'learning_rate': 0.1}
